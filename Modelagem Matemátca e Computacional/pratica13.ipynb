# %% [markdown]
# # **Modelagem Matemática e Computacional - Aula prática 13**
# ### Nome: Riquelme Freitas Gomes
# ### Data: 13/11/2023
# <br>
#
# # **Objetivo:**
# > ### Estudar e pôr em prática a modelagem matemática e a análise de dados utilizando Markov Chain, Equação de Kolmogorov e o Modelo GEMF.

# %% [markdown]
# # **Markov Chain**

# %% [markdown]
# ## **Markov Chain: Definição**
#
# * #### Uma Markov Chain é um processo estocástico que segue a propriedade de Markov, onde a probabilidade de transição para um estado futuro depende apenas do estado atual.
#
# * #### Formalmente, seja $X = \{X_0, X_1, X_2, . . .\}$ uma sequência de variáveis aleatórias representando os estados do sistema, a propriedade de Markov é definida por: $$P(X_{n+1} = j|X_n = i, X_{n−1}, . . . , X_0) = P(X_{n+1} = j|X_n = i)$$ para todos os estados $i$, $j$ e $n$.

# %% [markdown]
# ## **Markov Chain: Probabilidades de Transição**
#
# * #### Em uma Markov Chain, as probabilidades de transição são definidas como $P_{ij} = P(X_{n+1} = j|X_n = i)$, representando a probabilidade de transição do estado $i$ para o estado $j$.
#
# * #### A matriz de probabilidades de transição $P$ é uma matriz estocástica, onde cada elemento $P_{ij}$ é uma probabilidade não negativa e a soma das probabilidades em cada linha é igual a $1$.

# %% [markdown]
# ## **Markov Chain e suas Aplicações**
#
# * #### Markov Chain é um modelo matemático utilizado para descrever sistemas que evoluem ao longo do tempo, em que a probabilidade de uma transição futura depende apenas do estado atual.
#
# * #### É amplamente aplicado em várias áreas, como ciências da computação, física, economia, biologia, entre outras.
#
# * #### Exemplos de aplicações incluem análise de redes sociais, previsão de séries temporais, modelagem de processos químicos, entre outros.

# %% [markdown]
# # **Equação de Kolmogorov**

# %% [markdown]
# * #### A equação de Kolmogorov, também conhecida como equação de Chapman-Kolmogorov, descreve a evolução das probabilidades de transição em uma Markov Chain.
#
# * #### A equação pode ser descrita como: $$P_{ij}(n + m) = ∑_k P_{ik}(n)P_{kj}(m)$$ para todos os estados $i$, $j$, $n$ e m, onde $P_{ij}(n)$ representa a probabilidade de transição do estado $i$ para o estado $j$ em $n$ passos.
#
# * #### A Equação de Kolmogorov é uma equação diferencial ordinária (ODE) que descreve a evolução das probabilidades de transição em uma Markov Chain.
#
# * #### Ela relaciona as derivadas parciais das probabilidades de transição com as próprias probabilidades de transição.

# %% [markdown]
# ## **Equação de Kolmogorov: Formulação**
#
# * #### Seja $P_{ij}(t)$ a probabilidade de transição do estado $i$ para o estado $j$ em um tempo contínuo $t$.
#
# * #### A Equação de Kolmogorov pode ser formulada como uma ODE da
# seguinte forma: $$\frac{dP_{ij}(t)}{dt} = ∑_k Q_{ik}(t)P{kj}(t)-Q_{ij}(t)P{ij}(t)$$
# #### onde $Q_{ik}(t)$ é a taxa de transição do estado $i$ para o estado $k$ em $t$
#
# <br>
#
# #### Essa equação representa a taxa de mudança da probabilidade de transição do estado $i$ para o estado $j$ ao longo do tempo. O primeiro termo da equação, $∑_k Q_{ik}(t)P{kj}(t)$, representa as transições de outros estados para o estado $j$, enquanto o segundo termo, $Q_{ij}(t)P{ij}(t)$, representa a transição do estado $i$ para o estado $j$.

# %% [markdown]
# ## **Importância da Equação de Kolmogorov**
#
# * #### A equação de Kolmogorov permite calcular as probabilidades de transição em um processo estocástico, o que é essencial para entender o comportamento do sistema ao longo do tempo.
#
# * #### Ela fornece uma maneira de calcular a evolução das probabilidades de transição a partir das probabilidades de transição condicionais.
#
# * #### A equação de Kolmogorov é amplamente utilizada no estudo de Markov Chains para analisar propriedades como estabilidade, convergência, distribuição estacionária, entre outras.

# %% [markdown]
# # **GEMF**

# %% [markdown]
# ## **Modelos Determinísticos de Epidemia de Campo Médio**
#
# * #### Os modelos determinísticos de epidemia de campo médio têm sido bem-sucedidos em revelar diversas propriedades dinâmicas importantes dos processos estocásticos de propagação de epidemias em redes complexas.
#
# * #### Esses modelos isolam o impacto da topologia da rede na dinâmica de propagação.
#
# * #### Através de uma abordagem de aproximação de fechamento de campo médio, o tamanho das equações governantes é drasticamente reduzido, embora em detrimento da exatidão.
#
# * #### Isso permite o desenvolvimento de um conjunto de equações diferenciais não lineares que simplificam o tamanho do espaço de estados.
#
# * #### O modelo resultante, chamado de modelo de campo médio epidêmico generalizado (GEMF), possui uma estrutura simples caracterizada pelos elementos das matrizes de adjacência e das matrizes Laplacianas.
#
# * #### O GEMF permite analisar a propagação de epidemias de forma mais eficiente, considerando a influência da topologia da rede.

# %% [markdown]
# ## **Inclusão de Redes Complexas em Camadas**
#
# * #### Ao incluir múltiplos compartimentos e topologia de rede com várias camadas, muitos modelos de epidemia podem ser criados.
#
# * #### Os autores apresentam vários exemplos de modelos de epidemia, incluindo propagação de vírus e informações em redes de computadores e propagação de múltiplos patógenos em uma população hospedeira.
#
# * #### Esses modelos permitem estudar de forma mais abrangente e realista os processos de propagação em sistemas complexos.

# %% [markdown]
# ## **Modelo GEMF: Tamanho do Espaço de Estados**
#
# * #### O conjunto de equações diferenciais que descreve a evolução temporal das probabilidades de ocupação dos estados tem um tamanho de espaço de estados que cresce exponencialmente em relação ao número de agentes.
#
# * #### No entanto, com base em uma aproximação do tipo campo médio, os autores desenvolveram um conjunto de equações diferenciais não lineares com tamanho de espaço de estados que cresce linearmente.

# %% [markdown]
# ## **Modelo GEMF: Estrutura e Simplificação**
#
# * #### O sistema aproximado consiste em um conjunto de equações diferenciais ordinárias não lineares, chamado de modelo generalized epidemic mean-field (GEMF).
#
# * #### O modelo GEMF possui uma estrutura simples caracterizada pelos elementos das matrizes de adjacência das camadas de rede e pelas matrizes Laplacianas dos grafos de taxa de transição.
#
# * #### Essa simplificação permite o desenvolvimento de modelos mais precisos e eficazes para epidemias.

# %% [markdown]
# ## **Modelo GEMF: Aproximação do Campo Médio**
#
# * #### O modelo generalized epidemic mean-field (GEMF), apresentado no artigo, aproxima os valores esperados conjuntos em termos dos valores esperados marginais usando uma aproximação do tipo campo médio de primeira ordem.
#
# <br>
#
# * ![imagem_2023-12-03_200529821.png](data:image/png;base64,...)

# %% [markdown]
# ## **Modelo GEMF: Evolução Temporal Dos Valores Esperados**
#
# * #### A evolução temporal dos valores esperados é descrita por um conjunto de equações diferenciais ordinárias com $S$ estados:
#
# ![imagem_2023-12-03_201343832.png](data:image/png;base64,...)
#
# <br>
#
# #### É importante observar que a equação $(26)$ garante que a soma das probabilidades seja $1$ em qualquer momento, como $∑_{i=1}^{S} 𝔼[X_i(t)]=1$.

# %% [markdown]
# # **Experimentos com os códigos**

# %% [markdown]
# ## GEMFPy atualizado

# %%
##############################################################################
# Copyright (c) 2015, Network Science and Engineering Group (NetSE group)) at Kansas State University.
# http://ece.k-state.edu/sunflower_wiki/index.php/Main_Page
#
# Written by:
# Heman Shakeri:heman@ksu.edu
# All rights reserved.
#
# For details, see https://github.com/scalability-llnl/AutomaDeD
#
# This program is free software; you can redistribute it and/or modify
# it under the terms of the GNU General Public License (as published by
# the Free Software Foundation) version 2.1 dated February 1999.
#
# This program is distributed in the hope that it will be useful, but
# WITHOUT ANY WARRANTY; without even the IMPLIED WARRANTY OF
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the terms and
# conditions of the GNU General Public License for more details.
##############################################################################
import numpy as np
import networkx as nx
import scipy
import matplotlib.pyplot as plt
import random
import numpy.random as rand
# %matplotlib inline
from scipy.sparse import *
from scipy import *
from scipy.sparse import coo_matrix, bmat
import itertools
import math

# In[38]:

def NeighborhoodData ( N , L1 , L2, W):
    """
    A DB that gives the adjacent nodes (not necessary neighbors). For directed graphs we need NNeighborhoodData too.
    (Heman)
    """
    junk = np.sort ( L1 )
    index = np.argsort( L1 )


    NeighVec = L2[index]
    NeighWeight = W[index]

#     junk = np.sort ( dummy1 )
#     index = np.argsort( dummy1 )
#     for i in index:
#         NeighVec.extend([dummy2[i]])
#         NeighWeight.extend([dummy3[i]])

    l = len( junk );     d = np.zeros ( N , dtype=np.int32)
    I1 = np.zeros ( N , dtype=np.int32) ;
#     I1 = np.zeros ( N ) ;     I2 = np.zeros ( N )
    I1 = -np.ones ( N , dtype=np.int32) #starts from -1, since the first edge is zero
    i = 0
    while i+1 < l:  #i starts from zero
        node = junk[i]
        I1[node] = i #link number, starts from 0
        while junk[i + 1] == junk[i]:
            d[node] = d[node] + 1 ;
            i += 1
            if i+1 == l:
                break
        i += 1
    if i+1 == l:
        node = junk[i]; I1[node] = i; d[node] = 0
    I2 = I1 + d
    Temp1 = np.subtract(I2,I1)
    Temp2 = [int(I1[i]!=0) for i in range(len(I1)) ]
#     d = np.sum(Temp1, Temp2 )
    return NeighVec, I1, I2, d, NeighWeight
#--------------------------------------------------------
def NNeighborhoodData ( N , L1 , L2, W):
    """
    A DB that gives the adjacent nodes (not necessary neighbors). Useful only for directed graphs.
    (Heman)
    """
#     NNeighVec = []; NI1 = [] ; NI2 = [] ; dummy1 = L1; dummy2 = L2 ; dummy3 = W
#     NNeighWeight = []

#     junk = np.sort ( dummy2 )
#     index = np.argsort( dummy2 )
#     #instead of the following for loop: NNeighVec = dummy1[index]
#     for i in index:
#         NNeighVec.extend([dummy1[i]])
#         NNeighWeight.extend([dummy3[i]])


    junk = np.sort ( L2 )
    index = np.argsort( L2 )

    NNeighVec = L1[index]
    NNeighWeight = W[index]

    l = len( junk );     Nd = np.zeros ( N , dtype=np.int32)
#     NI1 = np.zeros ( N , dtype=int32)
    NI1 = -np.ones ( N , dtype=np.int32)
    i = 0
    I1 = [] ; I2 = [] ;
    while i+1 < l:  #i starts from zero
        node = junk[i]
        NI1[node] = i #link number, starts from 0
        while junk[i + 1] == junk[i]:
            Nd[node] = Nd[node] + 1 ;
            i += 1
            if i+1 == l:
                break
        i += 1
    if i+1 == l:
        node = junk[i]; NI1[node] = i; Nd[node] = 0
    NI2 = NI1 + Nd
    Temp1 = np.subtract(NI2, NI1)
    Temp2 = [int(NI1[i]!=0) for i in range(len(NI1)) ]
#     d = np.sum(Temp1, Temp2 )
    return NNeighVec, NI1, NI2, Nd, NNeighWeight


# In[48]:

def EIG1(G):
    adj=nx.to_scipy_sparse_matrix(G)
    k=adj.sum(axis=1);
    k=k/float(k.sum())
    err = 1; lambda1 = 0
    while err>1e-3:
        k = adj.dot(k)
#         k = np.dot(adj,k)
        temp = k.sum()
        err = temp - lambda1
        lambda1 = temp
        k = k/lambda1
        v1 = k
    return lambda1, v1
#----------------------------
def Initial_Cond_Gen(N, J, NJ, x0):
    """
    J = initial state for NJ number of whole population N
    Example :   x0 = np.zeros(N, dtype = int32)
                Initial_Cond_Gen(10, Para[1][0], 2, x0)
    """
    if sum(NJ) > N:
        return 'Oops! Initial infection is more than the total population'
    else:
        temp = np.random.permutation(N); nj=temp[0:sum(NJ)]
        for i in range(len(nj)):
            x0[nj[i]] = J
    return x0
#----------------------------
def rnd_draw(p):
    """
    To draw a sample using a probability distribution.
    """
    rng = np.random.default_rng()
    a = [0]
    a = np.append(a, np.cumsum(p[0:-1]))/np.sum(p)
    b = np.cumsum(p)/np.sum(p)
    toss = rng.random()
    k = np.intersect1d(np.nonzero(a<toss)[0], np.nonzero(b>=toss)[0])
    return k


# In[49]:

def MyNet(G, weight=None):

    """
    MyNet(G, weight='weight')
    """
    G_adj = nx.to_scipy_sparse_array(G, weight=weight)
    cx = G_adj.tocoo()
    L2 = cx.row
    L1 = cx.col
    W = cx.data
    N = G.number_of_nodes()
#     adj = [L1, L2, W, N]
    NeighVec, I1, I2, d, NeighWeight = NeighborhoodData ( N , L1 , L2, W)
    if nx.is_directed(G):
#     if True:
        NNeighVec, NI1, NI2, Nd, NNeighWeight = NNeighborhoodData ( N , L1 , L2, W) #ver2

#     Net = [NeighVec, I1, I2, d, adj, NeighWeight]
        Net = [NeighVec, I1, I2, d, NeighWeight, NNeighVec, NI1, NI2, NNeighWeight]#ver2
    else:
        Net = [NeighVec, I1, I2, d, NeighWeight]#ver2
    return Net


# In[50]:

def NetCmbn(NetSet):
    """
    Combine different network layers data. This function is used for directed networks.
    """

    if len(NetSet[0])>5: #Means it is directed
        Neigh = []; I1 = []; I2 = []; d = [];  NeighW = []; NNeigh = []; NI1 = []; NI2 = []; NNeighW = []
        for l in range(len(NetSet)):
            Neigh.append(NetSet[l][0]) #each layer append as a seperate: Neigh = [[Neigh_L1],[Neigh_L2]]
            I1.append(NetSet[l][1])    #I1 and I2 into each row of the new I1 and I2
            I2.append(NetSet[l][2])
            d.append(NetSet[l][3])
    #         adj.append(NetSet[l][4])
            NeighW.append(NetSet[l][4])
            NNeigh.append(NetSet[l][5]) #ver2
            NI1.append(NetSet[l][6])    #ver2
            NI2.append(NetSet[l][7])
            NNeighW.append(NetSet[l][8])
        Net = [Neigh,I1,I2,d, NeighW, NNeigh, NI1, NI2, NNeighW]
    else:
        Neigh = []; I1 = []; I2 = []; d = []; adj = []; NeighW = []
        for l in range(len(NetSet)):
            Neigh.append(NetSet[l][0]) #each layer append as a seperate: Neigh = [[Neigh_L1],[Neigh_L2]]
            I1.append(NetSet[l][1])    #I1 and I2 into each row of the new I1 and I2
            I2.append(NetSet[l][2])
            d.append(NetSet[l][3])
    #         adj.append(NetSet[l][4])
            NeighW.append(NetSet[l][4])
        Net = [Neigh,I1,I2,d, NeighW]
    return Net


# In[51]:

def GEMF_SIM(Para, Net, x0, StopCond, N, Directed = False):
    """
    An event-driven approach to simulate the stochastic process.

    """
    M = Para[0]
    q = Para[1]
    L = Para[2]
    A_d = Para[3]
    A_b = Para[4]
    Neigh = Net[0]; I1 = Net[1]; I2 = Net[2]; NeighW = Net[4]

    n_index = []; j_index = []; i_index = []
    #------------------------------
    bil = np.zeros((M,L))
    for l in range(L):
        bil[:,l] = A_b[l].sum(axis=1) #l'th column is row sum of l'th A_b
    #------------------------------
    bi = np.zeros((M,M,L))
    for i in range(M):
        for l in range(L):
            bi[i, :, l] = A_b[l][i,:]
    #------------------------------
    di = A_d.sum(axis=1) #The rate that we leave compartment i, due to nodal transitions
    #------------------------------
    #X = copy(x0)
    X = x0.astype(np.int32)#since compartments are just numbers we are using integer types. If

    #------------------------------
    Nq = np.zeros((L,N))
    #------------------------------ver 2
    for n in range(N):
        for l in range(L):
            Nln = Neigh[l][I1[l][n]:I2[l][n]+1]
            Nq[l][n] = sum((X[Nln]==q[l])*NeighW[l][I1[l][n]:I2[l][n]+1]        )
    #------------------------------ver2
    Rn = np.zeros(N)

    for n in range(N):
#         print 'di[X[n]]: '+str(di[X[n]])
#         print 'Nq[:,n]: '+str(Nq[:,n])
#         print 'bil[X[n],:]: '+str(bil[X[n],:])
#         print 'np.dot(bil[X[n],:],Nq[:,n]): '+str(np.dot(bil[X[n],:],Nq[:,n]))
        Rn[n] = di[X[n]] + np.dot(bil[X[n],:],Nq[:,n])
    R = sum(Rn)
    #------------------------------
    EventNum = StopCond[1]; RunTime= StopCond[1]
    ts = []
#     #------------------------------
    s=-1; Tf=0
    if len(Net)>5:
        NNeigh = Net[5]; NI1 = Net[6]; NI2 = Net[7]; NNeighW = Net[8]
        while Tf < RunTime:
            s +=1
            ts.append(-log( rand() )/R)
            #------------------------------ver 2
            ns = rnd_draw(Rn)
            iss = X[ns]

            js = rnd_draw( np.ravel(A_d[iss,:].T  + np.dot(bi[iss],Nq[:,ns]) ))
            n_index.extend(ns)
            j_index.extend(js)
            i_index.extend(iss)
    #        -------------------- % Updateing ver2
            X[ns] = js
            R -= Rn[ns]
            Rn[ns] = di[js] + np.dot(bil[js,:] , Nq[:,ns])
            R += Rn[ns]

            infl = (q == js).nonzero()[0]#inf is layers with influencer compartment
            for l in infl:
                Nln = NNeigh[l][NI1[l][ns]:NI2[l][ns]+1] #finding nodes that are adjacent to new infected
                IncreasEff = NNeighW[l][NI1[l][ns]:NI2[l][ns]+1]
                Nq[l][Nln] += IncreasEff #add the new infection weight edges
                k = 0
                for n in Nln:
                    Rn[n] += bil[X[n],l]*IncreasEff[k]
                    R += bil[X[n],l]*IncreasEff[k]
                    k +=1

            infl2 = (q == iss).nonzero()[0]#infl2 is layers with influencer compartment

    #         print 'inf2: '+str(inf2)
            for l in infl2: #finding influencer compartments
                Nln = NNeigh[int(l)][int(NI1[l][ns]):int(NI2[l][ns])+1] #finding nodes that are adjacent to new infected
                reducEff = NNeighW[int(l)][int(NI1[l][ns]):int(NI2[l][ns])+1]
                Nq[l][Nln] -= reducEff #subtract the new infection weight edges
                k = 0
                for n in Nln:
                    Rn[n] -= bil[X[n],l]*reducEff[k]
                    R -= bil[X[n],l]*reducEff[k]
                    k += 1
            if R < 1e-6:
                break
            Tf += ts[s]
    else:
        while Tf < RunTime:
            s +=1
            rng = np.random.default_rng()
            ts.append(-math.log( rng.random() )/R)
            #------------------------------ver 2
            ns = rnd_draw(Rn)
            iss = X[ns]

            js = rnd_draw( np.ravel(A_d[iss,:].T  + np.dot(bi[iss],Nq[:,ns]) ))
            n_index.extend(ns)
            j_index.extend(js)
            i_index.extend(iss)
    #        -------------------- % Updateing ver2
            X[ns] = js
            R -= Rn[ns]
            Rn[ns] = di[js] + np.dot(bil[js,:] , Nq[:,ns])
            R += Rn[ns]

            infl = (q == js).nonzero()[0]#inf is layers with influencer compartment
            for l in infl:
                Nln = Neigh[int(l)][int(I1[l][ns]):int(I2[l][ns])+1] #finding nodes that are adjacent to new infected
                IncreasEff = NeighW[int(l)][int(I1[l][ns]):int(I2[l][ns])+1]
                Nq[l][Nln] += IncreasEff #add the new infection weight edges
                k = 0
                for n in Nln:
                    Rn[n] += bil[X[n],l]*IncreasEff[k]
                    R += bil[X[n],l]*IncreasEff[k]
                    k +=1

            infl2 = (q == iss).nonzero()[0]#infl2 is layers with influencer compartment
    #         print 'inf2: '+str(inf2)
            for l in infl2: #finding influencer compartments
                Nln = Neigh[int(l)][int(I1[l][ns]):int(I2[l][ns])+1] #finding nodes that are adjacent to new infected
                reducEff = NeighW[int(l)][int(I1[l][ns]):int(I2[l][ns])+1]
                Nq[l][Nln] -= reducEff #subtract the new infection weight edges
                k = 0
                for n in Nln:
                    Rn[n] -= bil[X[n],l]*reducEff[k]
                    R -= bil[X[n],l]*reducEff[k]
                    k += 1
            if R < 1e-6:
                break
            Tf += ts[s]

    return ts, n_index, i_index, j_index


# In[52]:

def Post_Population(x0, M, N, ts, i_index, j_index):

    X0 = np.zeros((M,N))
    for i in range(N):
        X0[int(x0[i])][i] = 1
    T = [0]
    T.extend(np.cumsum(ts))
    StateCount = np.zeros((M,len(ts)+1))
    StateCount[:,0] = X0.sum(axis=1)
    DX = np.zeros(M); DX[i_index[0]] = -1; DX[j_index[0]] = 1
    StateCount[:,1] = StateCount[:,0]+DX
    for k in range(len(ts)):
        DX = np.zeros(M); DX[i_index[k]] = -1; DX[j_index[k]] = 1
        StateCount[:,k+1] = StateCount[:,k] + DX

    return T, StateCount


# In[53]:

def Para_SIS(delta,beta):
    M = 2; q = np.array([1]); L = len(q);
    A_d = np.zeros((M,M)); A_d[1][0] = delta
    A_b = []
    for l in range(L):
#         A_b.append(asmatrix(np.zeros((M,M))))
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta #[l][M][M]
    Para=[M,q,L,A_d,A_b]
    return Para


# In[54]:

def Para_SIR(delta, beta):
    M = 3; q = np.array([1]); L = len(q);
    A_d = np.zeros((M,M));   A_d[1][2] = delta
    A_b = []
    for l in range(L):
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta #[l][M][M]
    Para=[M,q,L,A_d,A_b]
    return Para


# In[55]:

def Para_SEIR(delta, beta, Lambda):
    M = 4; q = np.array([2]); L = len(q);
    A_d = np.zeros((M,M));   A_d[1][2] = Lambda; A_d[2][3] = delta #Lambda
    A_b = []
    for l in range(L):
#         A_b.append(asmatrix(np.zeros((M,M))))
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta #[l][M][M]
    Para=[M,q,L,A_d,A_b]
    return Para


# In[56]:

def Para_SAIS_Single(delta, beta, beta_a, kappa):
    M = 3; q = np.array([1]); L = len(q);
    A_d = np.zeros((M,M)); A_d[1][0] = delta
    A_b = []
    for l in range(L):
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta #[l][M][M]
    A_b[0][0][2] = kappa
    A_b[0][2][1] = beta_a
    Para = [M, q, L, A_d, A_b]
    return Para


# In[57]:

def Para_SAIS(delta, beta, beta_a, kappa, mu):
    M = 3; q = np.array([1,1]); L = len(q);
    A_d = np.zeros((M,M)); A_d[1][0] = delta
    A_b = []
    for l in range(L):
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta #[l][M][M]
    A_b[0][0][2] = kappa
    A_b[1][2][1] = beta_a
    A_b[1][0][2] = mu
    Para = [M, q, L, A_d, A_b]
    return Para


# In[58]:

def Para_SI1I2S(delta1, delta2, beta1, beta2):
    M = 3; q = np.array([1,2]); L = len(q);
    A_d = np.zeros((M,M)); A_d[1][0] = delta1; A_d[2][0] = delta2
    A_b = []
    for l in range(L):
        A_b.append(np.zeros((M,M)))
    A_b[0][0][1] = beta1 #[l][M][M]
    A_b[1][0][2] = beta2 #[l][M][M]

    Para = [M, q, L, A_d, A_b]
    return Para


# In[59]:

def MonteCarlo(Net, Para, StopCond, Init_inf, M, step, nsim, N, x_init = None ):
#     StopCond=['RunTime',500]
#     T_final = 80;
    t_interval = np.arange(0,StopCond[1], step)
    tsize = int(StopCond[1]/float(step))
    t_interval = np.linspace(0, StopCond[1], num=tsize)
    f = np.zeros(( M, tsize ))
#     nsim = 20;
    for n in range(nsim):
        x0 = Initial_Cond_Gen(N, Para[1][0], Init_inf, x0 = np.zeros(N, dtype = np.int32))
        [ts, n_index, i_index, j_index] = GEMF_SIM(Para, Net, x0, StopCond, N)
        [T, StateCount] = Post_Population(x0, M, N, ts, i_index, j_index)
        k=0
        y=np.zeros((M,tsize))
        NewT = T.extend([1000])
        for t in t_interval:
            ind, tr = np.histogram(t,bins = T)
            index = np.nonzero(ind)[0][0]
#             print index
            y[:,k] = StateCount[:, index]/N
            k+=1
        f += y;
    return t_interval, f/nsim


# In[60]:

def Simulation(G, Para, StopCond, Init_inf, nsim, Monte_Carlo = False, step = .1):
    """ ->
    >>> StopCond = ['RunTime', 20]
    """
    Net = NetCmbn([MyNet(G)])
    N = G.number_of_nodes()
    x0 = np.zeros(N)
    M = Para[0]
    if Monte_Carlo:
#         t_interval, f = MonteCarlo(StopCond, M, T_final, step, nsim, N)
        return MonteCarlo(Net, Para, StopCond, Init_inf, M, step, nsim, N, x_init = x0)
    else:
        x0 = Initial_Cond_Gen(N, Para[1][0], Init_inf, x0)
        ts, n_index, i_index, j_index = GEMF_SIM(Para, Net, x0, StopCond,N)
#         T, StateCount = Post_Population(x0, M, N, ts, i_index, j_index)
        return Post_Population(x0, M, N, ts, i_index, j_index)
    return T, StateCount
#-------------------------------------------------------------------------
def Sim_vacc(G, Para, C, Init_inf = 3, Num_of_Vacc = None, StopCond = None, nsim = None):
    """
    >>> t_interval, f_pass, f_rnd, f_outDeg, f_Mod = Sim_vacc(H, Para, Init_inf, C_Geo_d, Num_of_Vacc = 30, StopCond = ['RunTime', 30], nsim = 80)
    """
#     StopCond = StopCond
    G_Mod = G_Mod_vaccination(G, C, Num_of_Vacc)
    G_outDeg = G_Out_Deg_vaccination(G, Num_of_Vacc)
    G_rnd = G_rnd_vaccination(G, Num_of_Vacc)
#     G_LEig = G_LeftEig_vaccination(G, Num_of_Vacc)
    t_interval, f_pass = Simulation(G, Para, StopCond, Init_inf, nsim, Monte_Carlo = True )
    t_interval, f_rnd = Simulation(G_rnd, Para, StopCond, Init_inf, nsim, Monte_Carlo = True )
    t_interval, f_outDeg = Simulation(G_outDeg, Para, StopCond, Init_inf, nsim, Monte_Carlo = True )
    t_interval, f_Mod = Simulation(G_Mod, Para, StopCond, Init_inf, nsim, Monte_Carlo = True )
#     t_interval, f_LEig = Simulation(G_LEig, Para, StopCond2, Init_inf = Init_inf, Monte_Carlo = True)
    return t_interval, f_pass, f_rnd, f_outDeg, f_Mod


## Animation

# In[61]:

from matplotlib import animation
def animate_discrete_property_over_graph( g, model, steps, fig, n_index,i_index, j_index, comp, property = None,
                                         color_mapping = None, pos = None, Node_radius = None, **kwords ):
    """Draw a graph and animate the progress of a property over it. The
    property values are converted to colours that are then used to colour
    the nodes.
    """
    x0 = model[0]; n_index = model[1]; i_index = model[2]; j_index = model[3]

    # manipulate the axes, since this isn't a data plot
    ax = fig.gca()

    pos
    ax.grid(False)                # no grid
    ax.get_xaxis().set_ticks([])  # no ticks on the axes
    ax.get_yaxis().set_ticks([])
    nx.draw_networkx_edges(g, pos)

    if Node_radius == None:
        Node_radius = .02

    # draw the graph, keeping hold of the node markers
    nodeMarkers = []
    for v in g.nodes():
#         circ = plt.Circle(pos[v], radius = 0.02, zorder = 2)   # node markers at top of the z-order
        circ = plt.Circle(pos[v], radius = Node_radius, zorder = 2)   # node markers at top of the z-order
        ax.add_patch(circ)
        nodeMarkers.append({ 'node_key': v, 'marker': circ })

    # initialisation colours the markers according to the current
    # state of the property being tracked
    def colour_nodes():
        for nm in nodeMarkers:
            v = nm['node_key']
            state = g.nodes[v][property]
            c = color_mapping[state]
            marker = nm['marker']
            marker.set(color = c)

    # initialisation coours the markers according to the current
    # state of the property being tracked

#     comp = ['S', 'I' ]
    def init_state():
        """Initialise all node in the graph to be susceptible."""
        for i in g.nodes.keys():
            g.nodes[i]['state'] = comp[int(x0[i])]
        colour_nodes()

    # per-frame animation just iterates the model and then colours it
    # to reflect the changed property status of each node

    def frame(i):
        changing_node = n_index[i]
        new_comp = j_index[i]
        g.nodes[changing_node]['state'] = comp[new_comp]
        colour_nodes()


    #rc('animation', html='jshtml')
    # return the animation with the functions etc set up
    return animation.FuncAnimation(fig, frame, init_func = init_state, frames = steps, **kwords)

# %% [markdown]
# ## Código do professor corrigido

# %% [markdown]
# O código abaixo cria e visualiza um grafo geométrico aleatório usando a biblioteca NetworkX em Python. O resultado final é a visualização do grafo geométrico aleatório, onde a cor dos nós representa o comprimento do caminho mais curto a partir do nó mais próximo do centro. O nó mais próximo do centro é identificado e usado como ponto de referência para calcular os comprimentos dos caminhos mais curtos.

# %%
G=nx.random_geometric_graph(25, 0.3151)
pos=nx.get_node_attributes(G,'pos')

# find node near center (0.5,0.5)
dmin=1
ncenter=0
for n in pos:
    x,y=pos[n]
    d=(x-0.5)**2+(y-0.5)**2
    if d<dmin:
        ncenter=n
        dmin=d

# color by path length from node near center
p=nx.single_source_shortest_path_length(G,ncenter)

plt.figure(figsize=(8,8))
nx.draw_networkx(G, pos, node_size =200)

# plt.savefig('random_geometric_graph.png')
plt.show()

# %% [markdown]
# Ele cria um grafo geométrico aleatório com $25$ nós, onde os nós estão distribuídos aleatoriamente em um espaço 2D e as arestas são adicionadas se a distância euclidiana entre os nós é menor ou igual a $0.3151$. Obtém um dicionário de atributos de posição para cada nó no grafo. Essas posições representam as coordenadas (x, y) de cada nó no espaço 2D. Em seguida, o código encontra o nó mais próximo do centro do espaço $(0.5, 0.5)$. Ele calcula a distância euclidiana de cada nó para o centro e mantém o nó mais próximo e calcula os comprimentos dos caminhos mais curtos a partir do nó central (ncenter) para todos os outros nós no grafo usando o algoritmo de caminho mais curto.

# %% [markdown]
# O parâmetro 0.3151 no código determina a distância máxima para a criação de arestas no grafo geométrico aleatório. Ao alterar esse valor, você está efetivamente ajustando o raio de conectividade entre os nós no espaço 2D. Vamos explorar como diferentes valores desse parâmetro podem afetar o grafo resultante:

# %% [markdown]
# **Valores Pequenos:**
# * Se o valor for muito pequeno, poucas arestas serão formadas, e o grafo pode acabar consistindo em vários componentes isolados.
# * A conectividade será limitada, e a estrutura do grafo será mais esparsa.

# %%
G=nx.random_geometric_graph(25, 0.2)
pos=nx.get_node_attributes(G,'pos')

# find node near center (0.5,0.5)
dmin=1
ncenter=0
for n in pos:
    x,y=pos[n]
    d=(x-0.5)**2+(y-0.5)**2
    if d<dmin:
        ncenter=n
        dmin=d

# color by path length from node near center
p=nx.single_source_shortest_path_length(G,ncenter)

plt.figure(figsize=(8,8))
nx.draw_networkx(G, pos, node_size =200)

# plt.savefig('random_geometric_graph.png')
plt.show()

# %% [markdown]
# **Valores Grandes:**
# * À medida que o valor aumenta, mais arestas serão formadas entre os nós, resultando em um grafo mais densamente conectado.
# * Aumentar o valor pode levar a um único componente conectado, tornando o grafo mais semelhante a um grafo completo.

# %%
G=nx.random_geometric_graph(25, 0.8)
pos=nx.get_node_attributes(G,'pos')

# find node near center (0.5,0.5)
dmin=1
ncenter=0
for n in pos:
    x,y=pos[n]
    d=(x-0.5)**2+(y-0.5)**2
    if d<dmin:
        ncenter=n
        dmin=d

# color by path length from node near center
p=nx.single_source_shortest_path_length(G,ncenter)

plt.figure(figsize=(8,8))
nx.draw_networkx(G, pos, node_size =200)

# plt.savefig('random_geometric_graph.png')
plt.show()

# %% [markdown]
# Ajustar o parâmetro influenciará a topologia geral do grafo, impactando diretamente a distância média entre os nós, o número de componentes conectados, e a densidade das conexões. Isso é especialmente útil para explorar como a conectividade e a topologia do grafo variam com diferentes parâmetros em contextos específicos de aplicação.

# %% [markdown]
# ### **SIS**

# %% [markdown]
# O código a seguir está envolvido em simulações relacionadas a um modelo epidemiológico do tipo SIS (Susceptível-Infectado-Susceptível) em uma rede.

# %%
# G = nx.erdos_renyi_graph(10,.3)
N = G.number_of_nodes()

beta = 1.2; delta = 2;
Para = Para_SIS(delta,beta)

x0 = np.zeros(N)
x0 = Initial_Cond_Gen(N, Para[1][0], [2], x0)

Net = NetCmbn([MyNet(G)])
StopCond = ['RunTime', 10]

t, f = MonteCarlo(Net, Para,  StopCond, [1], 3, .1, 30, N, x_init = np.zeros(N) )
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# ...

# %% [markdown]
# Ele obtém o número de nós (indivíduos) na rede G e atribui a variável N. Define os parâmetros do modelo epidemiológico. beta representa a taxa de transmissão e delta é a taxa de recuperação. Gera um conjunto de parâmetros para o modelo SIS usando a função Para_SIS, que não está explicitamente fornecida no código. Presumivelmente, essa função cria um conjunto de parâmetros com base nos valores de delta e beta. Define um critério de parada para a simulação. Neste caso, a simulação será interrompida após 10 unidades de tempo de execução. Realiza uma simulação de Monte Carlo do modelo SIS.
#
# Em resumo, o código simula a propagação de uma doença infecciosa em uma rede usando o modelo SIS com parâmetros específicos e condições iniciais. A simulação é realizada para múltiplas realizações (Monte Carlo) e é interrompida após um determinado tempo de execução.

# %% [markdown]
# Este trecho de código é responsável por criar um gráfico para visualizar os resultados da simulação do modelo SIS.

# %%
fig2 = plt.figure(figsize=(10,5))
# for i in range(M):
# plt.plot(T, StateCount[0,:]/N,'r',label='Susceptible')
plt.plot(t,f[0,:],'r',label='Susceptible')
plt.plot(t,f[1,:],'b',label='Infected')
# plot(t,f[2,:],'g',label='Recovered')
# plt.savefig("SIS.png")

plt.xlabel('Time (day)')
plt.ylabel('Fraction of Population')
plt.title('SIS')
plt.legend(loc='upper center', shadow=True)
plt.show()
# plt.savefig("SIS_MonteCarlo.png")

# %% [markdown]
# O gráfico mostra como as frações da população suscetível e infectada variam ao longo do tempo no modelo SIS. As cores diferentes e a legenda ajudam a distinguir entre os dois grupos no gráfico.

# %% [markdown]
# Podemos experimentar com diferentes conjuntos de parâmetros para observar como eles afetam a dinâmica do modelo SIS.

# %%
# Novos parâmetros
beta_new = 1.5  # Aumentando a taxa de transmissão
delta_new = 1.5  # Ajustando a taxa de recuperação

# Atualizando os parâmetros no código
beta = beta_new
delta = delta_new
Para_new = Para_SIS(delta, beta)

# Executando a simulação com os novos parâmetros
t_new, f_new = MonteCarlo(Net, Para_new, StopCond, [1], 3, 0.1, 30, N, x_init=np.zeros(N))
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# /usr/local/lib/python3.10/dist-packages/numpy/lib/histograms.py:429: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   bin_edges = np.asarray(bins)
# ...

# %%
# Criando um novo gráfico com os resultados
fig_new = plt.figure(figsize=(10, 5))
plt.plot(t_new, f_new[0, :], 'r', label='Susceptible')
plt.plot(t_new, f_new[1, :], 'b', label='Infected')

# Adicionando rótulos e legendas
plt.xlabel('Time (day)')
plt.ylabel('Fraction of Population')
plt.title('SIS with New Parameters')
plt.legend(loc='upper center', shadow=True)

# Exibindo o novo gráfico
plt.show()

# %% [markdown]
# Neste exemplo, eu ajustei a taxa de transmissão (beta_new) para um valor maior e a taxa de recuperação (delta_new) para um valor menor. Essas mudanças podem influenciar a propagação da doença e, consequentemente, os resultados da simulação. Vemos que, nesse caso, o número de suscetíveis se estabiliza em um valor menor enquanto o número de infectados se estabiliza em um valor maior.

# %% [markdown]
# O trecho de código abaixo está relacionado à simulação do Modelo GEMF (Generalized Epidemic Modeling Framework) para um sistema do tipo SIS (Susceptível-Infectado-Suscetível) em uma rede.

# %%
ts, n_index, i_index, j_index = GEMF_SIM(Para, Net, x0, StopCond,N)

M = Para[0]
T, StateCount = Post_Population(x0, M, N, ts, i_index, j_index)

fig = plt.figure(figsize=(10,5))
# for i in range(M):
# plt.plot(T, StateCount[0,:]/N,'r',label='Susceptible')
plt.plot(T, StateCount[0,:]/N,'r',label='Susceptible')
plt.plot(T, StateCount[1,:]/N,'k',label='Infected')
# plt.plot(T, StateCount[2,:]/N,'y',label='Recovered')

plt.xlabel('Time (day)')
plt.ylabel('Fraction of Population')
plt.title('SIS')
plt.legend(loc='upper center', shadow=True)
plt.show()
# plt.savefig("SIS.png")
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# /usr/local/lib/python3.10/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %% [markdown]
# O resultado é um gráfico que representa a dinâmica do modelo SIS simulado usando o Modelo GEMF. As curvas mostram como as frações de suscetíveis e infectados evoluem ao longo do tempo para múltiplos cenários simulados. Experimentemos o código com diferentes conjuntos de parâmetros. Aqui está uma versão modificada do código com parâmetros ajustados:

# %% [markdown]
# ### **SIR**

# %% [markdown]
# Aqui fazemos a inicialização de variáveis e configuração de parâmetros para simulação de um modelo epidemiológico do tipo SIR (Susceptível-Infectado-Recuperado) em uma rede.

# %%
# G = nx.erdos_renyi_graph(10,.3)
N = G.number_of_nodes()

beta = 1.2; delta = 2;
Para = Para_SIR(delta,beta)

x0 = np.zeros(N)
x0 = Initial_Cond_Gen(N, Para[1][0], [2], x0)

Net = NetCmbn([MyNet(G)])
StopCond = ['RunTime', 10]

# %%
t, f = MonteCarlo(Net, Para,  StopCond, [1], 3, .1, 50, N, x_init = np.zeros(N) )
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# ...

# %% [markdown]
# A função MonteCarlo realiza a simulação propriamente dita, executando o modelo SIR várias vezes para diferentes realizações ou cenários e registrando os resultados ao longo do tempo. Os resultados são retornados como duas variáveis, t e f, onde t é um vetor representando os pontos temporais da simulação e f é uma matriz que contém as informações dos estados da população ao longo do tempo para cada realização simulada.

# %%
import matplotlib.pyplot as plt

fig2 = plt.figure(figsize=(10,5))
# for i in range(M):
# plt.plot(T, StateCount[0,:]/N,'r',label='Susceptible')
plt.plot(t,f[0,:],'r',label='Susceptible')
plt.plot(t,f[1,:],'b',label='Infected')
plt.plot(t,f[2,:],'g',label='Recovered')

plt.xlabel('Time (day)')
plt.ylabel('Fraction of Population')
plt.title('SIR')
legend = plt.legend(loc='upper center', shadow=True)

# %% [markdown]
# Esse código gera um gráfico que mostra como as frações da população suscetível, infectada e recuperada evoluem ao longo do tempo para a simulação do modelo SIS usando a técnica de Monte Carlo. A legenda destaca as diferentes curvas no gráfico para cada condição. Vamos fazer algumas mudanças nos parâmetros e condições iniciais para observar como elas afetam a simulação do modelo SIS

# %%
# G = nx.erdos_renyi_graph(10,.3)
N = G.number_of_nodes()

beta = 0.5; delta = 0.1;
Para = Para_SIR(delta,beta)

x0 = np.zeros(N)
x0 = Initial_Cond_Gen(N, Para[1][0], [2], x0)

Net = NetCmbn([MyNet(G)])
StopCond = ['RunTime', 10]

# %%
t, f = MonteCarlo(Net, Para,  StopCond, [1], 3, .1, 50, N, x_init = np.zeros(N) )
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:43: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   result = getattr(asarray(obj), method)(*args, **kwds)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3156: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   return asarray(a).ndim
# ...

# %%
import matplotlib.pyplot as plt

fig2 = plt.figure(figsize=(10,5))
# for i in range(M):
# plt.plot(T, StateCount[0,:]/N,'r',label='Susceptible')
plt.plot(t,f[0,:],'r',label='Susceptible')
plt.plot(t,f[1,:],'b',label='Infected')
plt.plot(t,f[2,:],'g',label='Recovered')

plt.xlabel('Time (day)')
plt.ylabel('Fraction of Population')
plt.title('SIR')
legend = plt.legend(loc='upper center', shadow=True)

# %% [markdown]
# É possível perceber que as mudanças nos parâmetros (beta e delta) já foram suficientes para alterar completamente o comportamento de cada curva do modelo: Suscetíveis, Infectados e Recuperados.

# %% [markdown]
# # **Conclusão**
#
# #### Em conclusão, a aplicação das Cadeias de Markov, a formulação das Equações de Kolmogorov e a implementação do Modelo GEMF oferecem uma poderosa estrutura analítica para compreender e modelar uma variedade de processos estocásticos em diferentes campos. A abordagem baseada em Markov Chain permitiu-nos descrever a evolução dinâmica de sistemas nos quais a transição de um estado para outro é determinada exclusivamente pelo estado atual, enquanto as Equações de Kolmogorov forneceram uma fundação matemática robusta para analisar a probabilidade de transição entre estados em um intervalo contínuo de tempo.
#
# #### O Modelo GEMF, por sua vez, apresenta uma extensão valiosa ao considerar fatores externos e a influência de variáveis exógenas sobre a dinâmica do sistema. Essa abordagem mais abrangente e flexível é especialmente relevante em cenários complexos nos quais a interação entre diferentes componentes do sistema é crucial para a compreensão do comportamento global. Ao incorporar elementos de mobilidade, expansão e contração, o Modelo GEMF revela-se uma ferramenta valiosa para simular e prever a dinâmica de sistemas complexos ao longo do tempo.
#
# #### Em síntese, a combinação dessas técnicas proporciona uma visão aprofundada dos processos estocásticos, oferecendo uma base sólida para análises quantitativas e tomadas de decisão informadas em uma ampla gama de contextos. A utilização conjunta de Markov Chain, Equações de Kolmogorov e o Modelo GEMF representa um avanço significativo na modelagem de sistemas dinâmicos, contribuindo para a compreensão e previsão de fenômenos complexos em áreas tão diversas como finanças, biologia, engenharia e muito mais.

# %% [markdown]
# # **Fontes e referências**
#
# 1. Uma Iniciação aos Sistemas Dinâmicos Estocásticos
# 2. Generalized Epidemic Mean-Field Model for Spreading Processes Over Multilayer Complex Networks
# 3. GEMFsim: A Stochastic Simulator for the Generalized Epidemic Modeling Framework. https://arxiv.org/pdf/1604.02175.pdf
# 4. Mathematical Modeling of Epidemics on Complex Networks. https://danielpakasa.medium.com/mathematical-modeling-of-epidemics-on-complex-networks-eee4f76739f
